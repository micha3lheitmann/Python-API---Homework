# %% [markdown]
# # WeatherPy
# ----
#
# #### Analysis
# •	Latitude and temperature have a clear correlation
# •	As expected, the weather warms as we approach the equator. The southern hemisphere tends to be warmer this time of year than the northern hemisphere
# •	There is no strong relationship between latitude and cloudiness. However, it is interesting that it is more likely to be zero clouds or 80 to 100 percent cloudy.
# •	There seems to be a correlation between strong isolated wind and higher latitudes in the northern hemisphere
# •	Across all latitudes wind tends to cluster around 5 mph
# •	There is no strong relationship between latitude and humidity. however there is a slightly larger cluster of northern   hemisphere cities with high humidity (above 60% humidity)
# •	Final Note – Because land mass and populations are not divided equally between latitudes, finding correlations based on latitude may not be an effective way to analyze weather data

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "\Desktop\PyAPI\cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %%
# define url
temp_units = "imperial"
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | ostrovnoy
# Processing Record 2 of Set 1 | cidreira
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | clarence town
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | skibbereen
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | lambarene
# Processing Record 12 of Set 1 | carnarvon
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | kozhva
# Processing Record 15 of Set 1 | sao joao da barra
# Processing Record 16 of Set 1 | deputatskiy
# Processing Record 17 of Set 1 | acapulco
# City not found. Skipping...
# Processing Record 18 of Set 1 | buchanan
# Processing Record 19 of Set 1 | prince rupert
# Processing Record 20 of Set 1 | luderitz
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | nizhneudinsk
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | avera
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | meulaboh
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | bangassou
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | grand river south east
# Processing Record 38 of Set 1 | bilma
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | vao
# Processing Record 41 of Set 1 | tromso
# City not found. Skipping...
# Processing Record 42 of Set 1 | inhambane
# Processing Record 43 of Set 1 | faanui
# Processing Record 44 of Set 1 | lavrentiya
# Processing Record 45 of Set 1 | chifeng
# Processing Record 46 of Set 1 | murfreesboro
# Processing Record 47 of Set 1 | gimli
# Processing Record 48 of Set 1 | cayenne
# Processing Record 49 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | haysville
# Processing Record 5 of Set 2 | guerrero negro
# Processing Record 6 of Set 2 | kysyl-syr
# Processing Record 7 of Set 2 | kruisfontein
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | sosua
# Processing Record 10 of Set 2 | san quintin
# City not found. Skipping...
# Processing Record 11 of Set 2 | latung
# Processing Record 12 of Set 2 | lahaina
# Processing Record 13 of Set 2 | ayabaca
# Processing Record 14 of Set 2 | yerbogachen
# Processing Record 15 of Set 2 | altamont
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | puerto el triunfo
# Processing Record 18 of Set 2 | narsaq
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | jaggayyapeta
# Processing Record 21 of Set 2 | digras
# Processing Record 22 of Set 2 | kaitangata
# City not found. Skipping...
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | muisne
# Processing Record 25 of Set 2 | loukhi
# Processing Record 26 of Set 2 | oistins
# City not found. Skipping...
# Processing Record 27 of Set 2 | talara
# Processing Record 28 of Set 2 | opuwo
# Processing Record 29 of Set 2 | sao filipe
# Processing Record 30 of Set 2 | buraydah
# Processing Record 31 of Set 2 | nagamangala
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | ravar
# Processing Record 34 of Set 2 | tommot
# Processing Record 35 of Set 2 | bundaberg
# Processing Record 36 of Set 2 | gwadar
# Processing Record 37 of Set 2 | mys shmidta
# Processing Record 38 of Set 2 | upernavik
# Processing Record 39 of Set 2 | omsukchan
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | otradnoye
# Processing Record 42 of Set 2 | hovd
# Processing Record 43 of Set 2 | rjukan
# Processing Record 44 of Set 2 | chimore
# City not found. Skipping...
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | hokitika
# Processing Record 47 of Set 2 | hasaki
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | roma
# Processing Record 1 of Set 3 | padang
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 3 | karratha
# Processing Record 3 of Set 3 | victoria
# Processing Record 4 of Set 3 | norman wells
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | gladstone
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | ardesen
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | codajas
# Processing Record 11 of Set 3 | azul
# Processing Record 12 of Set 3 | leninskoye
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | vila velha
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | linguere
# Processing Record 19 of Set 3 | zalantun
# Processing Record 20 of Set 3 | karlskoga
# City not found. Skipping...
# Processing Record 21 of Set 3 | beringovskiy
# Processing Record 22 of Set 3 | geraldton
# City not found. Skipping...
# Processing Record 23 of Set 3 | nara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 3 | batesville
# Processing Record 25 of Set 3 | novyy starodub
# Processing Record 26 of Set 3 | drumnadrochit
# Processing Record 27 of Set 3 | salamanca
# Processing Record 28 of Set 3 | yar-sale
# Processing Record 29 of Set 3 | khasan
# Processing Record 30 of Set 3 | kahului
# Processing Record 31 of Set 3 | harper
# Processing Record 32 of Set 3 | sept-iles
# Processing Record 33 of Set 3 | kadnikov
# Processing Record 34 of Set 3 | portage
# Processing Record 35 of Set 3 | gat
# Processing Record 36 of Set 3 | westport
# City not found. Skipping...
# Processing Record 37 of Set 3 | kalivia
# Processing Record 38 of Set 3 | hamilton
# Processing Record 39 of Set 3 | kirakira
# Processing Record 40 of Set 3 | sur
# Processing Record 41 of Set 3 | chokurdakh
# City not found. Skipping...
# Processing Record 42 of Set 3 | rudsar
# Processing Record 43 of Set 3 | sinnamary
# Processing Record 44 of Set 3 | tura
# Processing Record 45 of Set 3 | surt
# Processing Record 46 of Set 3 | kharp
# Processing Record 47 of Set 3 | georgetown
# Processing Record 48 of Set 3 | portland
# Processing Record 49 of Set 3 | kavieng
# Processing Record 1 of Set 4 | san patricio
# Processing Record 2 of Set 4 | ribeira grande
# Processing Record 3 of Set 4 | vostok
# Processing Record 4 of Set 4 | kailua
# Processing Record 5 of Set 4 | oxford
# Processing Record 6 of Set 4 | churapcha
# Processing Record 7 of Set 4 | okha
# Processing Record 8 of Set 4 | bristol
# Processing Record 9 of Set 4 | ketchikan
# Processing Record 10 of Set 4 | qaqortoq
# Processing Record 11 of Set 4 | grand-santi
# Processing Record 12 of Set 4 | kodiak
# City not found. Skipping...
# Processing Record 13 of Set 4 | severnyy
# Processing Record 14 of Set 4 | airai
# Processing Record 15 of Set 4 | puerto escondido
# Processing Record 16 of Set 4 | zeya
# Processing Record 17 of Set 4 | ilulissat
# Processing Record 18 of Set 4 | mwanza
# Processing Record 19 of Set 4 | solnechnyy
# Processing Record 20 of Set 4 | pevek
# Processing Record 21 of Set 4 | santiago del estero
# Processing Record 22 of Set 4 | cleethorpes
# City not found. Skipping...
# Processing Record 23 of Set 4 | pangody
# City not found. Skipping...
# Processing Record 24 of Set 4 | new norfolk
# Processing Record 25 of Set 4 | saint-joseph
# City not found. Skipping...
# Processing Record 26 of Set 4 | pirgos
# City not found. Skipping...
# Processing Record 27 of Set 4 | srednekolymsk
# Processing Record 28 of Set 4 | port keats
# Processing Record 29 of Set 4 | ajaccio
# Processing Record 30 of Set 4 | naze
# Processing Record 31 of Set 4 | mahon
# Processing Record 32 of Set 4 | sobolevo
# Processing Record 33 of Set 4 | cherskiy
# Processing Record 34 of Set 4 | linxia
# Processing Record 35 of Set 4 | fortuna
# Processing Record 36 of Set 4 | isangel
# City not found. Skipping...
# Processing Record 37 of Set 4 | asau
# Processing Record 38 of Set 4 | itaituba
# Processing Record 39 of Set 4 | ust-kuyga
# Processing Record 40 of Set 4 | saint-philippe
# Processing Record 41 of Set 4 | nago
# Processing Record 42 of Set 4 | port hedland
# Processing Record 43 of Set 4 | elbistan
# Processing Record 44 of Set 4 | niquelandia
# Processing Record 45 of Set 4 | addi ugri
# Processing Record 46 of Set 4 | verkh-usugli
# Processing Record 47 of Set 4 | yenagoa
# Processing Record 48 of Set 4 | santa maria
# Processing Record 49 of Set 4 | pangnirtung
# Processing Record 1 of Set 5 | moses lake
# Processing Record 2 of Set 5 | saint-augustin
# Processing Record 3 of Set 5 | bandarbeyla
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 5 | sovetskiy
# Processing Record 5 of Set 5 | hofn
# Processing Record 6 of Set 5 | shimoda
# City not found. Skipping...
# Processing Record 7 of Set 5 | ranfurly
# City not found. Skipping...
# Processing Record 8 of Set 5 | gambela
# City not found. Skipping...
# Processing Record 9 of Set 5 | flin flon
# Processing Record 10 of Set 5 | tasiilaq
# Processing Record 11 of Set 5 | hobyo
# Processing Record 12 of Set 5 | san rafael
# Processing Record 13 of Set 5 | ust-nera
# Processing Record 14 of Set 5 | jalu
# Processing Record 15 of Set 5 | khatanga
# Processing Record 16 of Set 5 | kingaroy
# Processing Record 17 of Set 5 | dunmore east
# Processing Record 18 of Set 5 | shache
# Processing Record 19 of Set 5 | ust-maya
# Processing Record 20 of Set 5 | bathsheba
# Processing Record 21 of Set 5 | fairbanks
# Processing Record 22 of Set 5 | severo-kurilsk
# Processing Record 23 of Set 5 | panzhihua
# City not found. Skipping...
# Processing Record 24 of Set 5 | mar del plata
# Processing Record 25 of Set 5 | bengkulu
# Processing Record 26 of Set 5 | ponta do sol
# City not found. Skipping...
# Processing Record 27 of Set 5 | salamiyah
# Processing Record 28 of Set 5 | katobu
# Processing Record 29 of Set 5 | saldanha
# City not found. Skipping...
# Processing Record 30 of Set 5 | kununurra
# Processing Record 31 of Set 5 | emba
# Processing Record 32 of Set 5 | sitka
# Processing Record 33 of Set 5 | rio grande
# Processing Record 34 of Set 5 | reftinskiy
# Processing Record 35 of Set 5 | puerto ayacucho
# Processing Record 36 of Set 5 | mandan
# Processing Record 37 of Set 5 | cozumel
# Processing Record 38 of Set 5 | muros
# Processing Record 39 of Set 5 | kulaman
# Processing Record 40 of Set 5 | amot
# Processing Record 41 of Set 5 | karpathos
# Processing Record 42 of Set 5 | itinga
# Processing Record 43 of Set 5 | rawson
# Processing Record 44 of Set 5 | semey
# Processing Record 45 of Set 5 | mudanjiang
# Processing Record 46 of Set 5 | alta floresta
# Processing Record 47 of Set 5 | isla mujeres
# Processing Record 48 of Set 5 | marsh harbour
# Processing Record 49 of Set 5 | ranong
# Processing Record 1 of Set 6 | belyy yar
# Processing Record 2 of Set 6 | broome
# Processing Record 3 of Set 6 | ugoofaaru
# Processing Record 4 of Set 6 | monte cristi
# Processing Record 5 of Set 6 | namibe
# Processing Record 6 of Set 6 | sao joao del rei
# Processing Record 7 of Set 6 | codrington
# Processing Record 8 of Set 6 | marienburg
# Processing Record 9 of Set 6 | visnes
# Processing Record 10 of Set 6 | kargasok
# Processing Record 11 of Set 6 | apac
# Processing Record 12 of Set 6 | vestmannaeyjar
# Processing Record 13 of Set 6 | jutai
# Processing Record 14 of Set 6 | sinjai
# Processing Record 15 of Set 6 | miranda
# Processing Record 16 of Set 6 | ust-kachka
# Processing Record 17 of Set 6 | manokwari
# Processing Record 18 of Set 6 | kipini
# Processing Record 19 of Set 6 | nabire
# Processing Record 20 of Set 6 | marsa matruh
# Processing Record 21 of Set 6 | gigmoto
# Processing Record 22 of Set 6 | brigantine
# Processing Record 23 of Set 6 | mindelo
# Processing Record 24 of Set 6 | grindavik
# Processing Record 25 of Set 6 | benguela
# Processing Record 26 of Set 6 | date
# Processing Record 27 of Set 6 | nome
# Processing Record 28 of Set 6 | merauke
# Processing Record 29 of Set 6 | california city
# Processing Record 30 of Set 6 | loralai
# Processing Record 31 of Set 6 | clyde river
# Processing Record 32 of Set 6 | springbok
# Processing Record 33 of Set 6 | faridabad
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 6 | jumla
# Processing Record 35 of Set 6 | itarema
# Processing Record 36 of Set 6 | beyneu
# Processing Record 37 of Set 6 | coihaique
# Processing Record 38 of Set 6 | viedma
# City not found. Skipping...
# Processing Record 39 of Set 6 | angola
# Processing Record 40 of Set 6 | kitale
# Processing Record 41 of Set 6 | charters towers
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 6 | visby
# City not found. Skipping...
# Processing Record 43 of Set 6 | lata
# Processing Record 44 of Set 6 | fasa
# Processing Record 45 of Set 6 | provideniya
# Processing Record 46 of Set 6 | yuncheng
# Processing Record 47 of Set 6 | port lincoln
# Processing Record 48 of Set 6 | bethel
# Processing Record 49 of Set 6 | hambantota
# Processing Record 1 of Set 7 | paengaroa
# Processing Record 2 of Set 7 | lufilufi
# Processing Record 3 of Set 7 | berdigestyakh
# Processing Record 4 of Set 7 | lompoc
# Processing Record 5 of Set 7 | tiksi
# Processing Record 6 of Set 7 | santo domingo de guzman
# Processing Record 7 of Set 7 | vila franca do campo
# Processing Record 8 of Set 7 | bonavista
# Processing Record 9 of Set 7 | olafsvik
# Processing Record 10 of Set 7 | rennes
# Processing Record 11 of Set 7 | angoche
# Processing Record 12 of Set 7 | kirkuk
# Processing Record 13 of Set 7 | houyet
# Processing Record 14 of Set 7 | coquimbo
# Processing Record 15 of Set 7 | mount gambier
# Processing Record 16 of Set 7 | camacha
# Processing Record 17 of Set 7 | salalah
# Processing Record 18 of Set 7 | san andres
# Processing Record 19 of Set 7 | irece
# Processing Record 20 of Set 7 | laguna
# Processing Record 21 of Set 7 | garmsar
# Processing Record 22 of Set 7 | esperance
# Processing Record 23 of Set 7 | calabar
# Processing Record 24 of Set 7 | dawlatabad
# Processing Record 25 of Set 7 | sergeyevka
# Processing Record 26 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 7 | puerto del rosario
# Processing Record 28 of Set 7 | oloron-sainte-marie
# Processing Record 29 of Set 7 | byron bay
# City not found. Skipping...
# Processing Record 30 of Set 7 | berbera
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 7 | wanning
# Processing Record 32 of Set 7 | okhotsk
# Processing Record 33 of Set 7 | nanakuli
# Processing Record 34 of Set 7 | jabinyanah
# Processing Record 35 of Set 7 | bintulu
# Processing Record 36 of Set 7 | kirillov
# Processing Record 37 of Set 7 | novyy urgal
# Processing Record 38 of Set 7 | lasa
# Processing Record 39 of Set 7 | tocopilla
# Processing Record 40 of Set 7 | dasoguz
# Processing Record 41 of Set 7 | manono
# City not found. Skipping...
# Processing Record 42 of Set 7 | dwarka
# Processing Record 43 of Set 7 | pedernales
# Processing Record 44 of Set 7 | krasnoselkup
# Processing Record 45 of Set 7 | alofi
# Processing Record 46 of Set 7 | nacozari
# Processing Record 47 of Set 7 | ahipara
# Processing Record 48 of Set 7 | tombouctou
# Processing Record 49 of Set 7 | sydney
# Processing Record 1 of Set 8 | davila
# City not found. Skipping...
# Processing Record 2 of Set 8 | rieti
# Processing Record 3 of Set 8 | mawlaik
# Processing Record 4 of Set 8 | tabas
# Processing Record 5 of Set 8 | baculin
# Processing Record 6 of Set 8 | villa florida
# Processing Record 7 of Set 8 | lagoa
# Processing Record 8 of Set 8 | kayerkan
# Processing Record 9 of Set 8 | constitucion
# Processing Record 10 of Set 8 | port macquarie
# Processing Record 11 of Set 8 | anse-bertrand
# Processing Record 12 of Set 8 | dingle
# Processing Record 13 of Set 8 | sakharovo
# City not found. Skipping...
# Processing Record 14 of Set 8 | molina
# Processing Record 15 of Set 8 | murmashi
# Processing Record 16 of Set 8 | amambai
# Processing Record 17 of Set 8 | craigieburn
# Processing Record 18 of Set 8 | tessalit
# City not found. Skipping...
# Processing Record 19 of Set 8 | aswan
# Processing Record 20 of Set 8 | bangui
# Processing Record 21 of Set 8 | akdepe
# Processing Record 22 of Set 8 | bambous virieux
# Processing Record 23 of Set 8 | sarangani
# Processing Record 24 of Set 8 | richards bay
# Processing Record 25 of Set 8 | mareeba
# City not found. Skipping...
# Processing Record 26 of Set 8 | fukue
# Processing Record 27 of Set 8 | safaga
# Processing Record 28 of Set 8 | mazatan
# Processing Record 29 of Set 8 | khani
# Processing Record 30 of Set 8 | vicente guerrero
# Processing Record 31 of Set 8 | sjenica
# Processing Record 32 of Set 8 | eatonton
# City not found. Skipping...
# Processing Record 33 of Set 8 | port pirie
# Processing Record 34 of Set 8 | pisco
# Processing Record 35 of Set 8 | zhanakorgan
# Processing Record 36 of Set 8 | maymyo
# Processing Record 37 of Set 8 | husavik
# Processing Record 38 of Set 8 | sheridan
# Processing Record 39 of Set 8 | katsuura
# City not found. Skipping...
# Processing Record 40 of Set 8 | abu dhabi
# Processing Record 41 of Set 8 | teya
# City not found. Skipping...
# Processing Record 42 of Set 8 | yaguara
# Processing Record 43 of Set 8 | central point
# Processing Record 44 of Set 8 | suzaka
# Processing Record 45 of Set 8 | svetlyy
# Processing Record 46 of Set 8 | vila do maio
# Processing Record 47 of Set 8 | batagay
# Processing Record 48 of Set 8 | shakawe
# Processing Record 49 of Set 8 | kurilsk
# Processing Record 1 of Set 9 | aykhal
# Processing Record 2 of Set 9 | mugumu
# Processing Record 3 of Set 9 | farah
# Processing Record 4 of Set 9 | klyuchi
# Processing Record 5 of Set 9 | tuatapere
# Processing Record 6 of Set 9 | moussoro
# Processing Record 7 of Set 9 | mitsamiouli
# Processing Record 8 of Set 9 | sarh
# Processing Record 9 of Set 9 | dossor
# Processing Record 10 of Set 9 | tornio
# Processing Record 11 of Set 9 | caravelas
# Processing Record 12 of Set 9 | uhlove
# Processing Record 13 of Set 9 | cabedelo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 9 | san cristobal
# City not found. Skipping...
# Processing Record 15 of Set 9 | mujiayingzi
# City not found. Skipping...
# Processing Record 16 of Set 9 | camana
# Processing Record 17 of Set 9 | waddan
# City not found. Skipping...
# Processing Record 18 of Set 9 | rio gallegos
# Processing Record 19 of Set 9 | kavaratti
# Processing Record 20 of Set 9 | mbandaka
# Processing Record 21 of Set 9 | tirthahalli
# Processing Record 22 of Set 9 | erzin
# Processing Record 23 of Set 9 | moron
# Processing Record 24 of Set 9 | lokosovo
# Processing Record 25 of Set 9 | terrace bay
# Processing Record 26 of Set 9 | ochakiv
# Processing Record 27 of Set 9 | oga
# Processing Record 28 of Set 9 | lomza
# Processing Record 29 of Set 9 | srandakan
# Processing Record 30 of Set 9 | kerikeri
# Processing Record 31 of Set 9 | rocha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 9 | botwood
# Processing Record 33 of Set 9 | zyryanovsk
# Processing Record 34 of Set 9 | dauriya
# Processing Record 35 of Set 9 | formoso do araguaia
# Processing Record 36 of Set 9 | klaksvik
# Processing Record 37 of Set 9 | kedrovyy
# Processing Record 38 of Set 9 | imatra
# Processing Record 39 of Set 9 | iqaluit
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 9 | araouane
# Processing Record 41 of Set 9 | christchurch
# Processing Record 42 of Set 9 | gravelbourg
# Processing Record 43 of Set 9 | celestun
# City not found. Skipping...
# Processing Record 44 of Set 9 | along
# Processing Record 45 of Set 9 | anadyr
# Processing Record 46 of Set 9 | bolu
# Processing Record 47 of Set 9 | lorengau
# Processing Record 48 of Set 9 | lipari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 9 | sheopur
# Processing Record 1 of Set 10 | neyshabur
# Processing Record 2 of Set 10 | ambilobe
# Processing Record 3 of Set 10 | marsaxlokk
# City not found. Skipping...
# Processing Record 4 of Set 10 | gushikawa
# Processing Record 5 of Set 10 | alihe
# Processing Record 6 of Set 10 | kyrylivka
# Processing Record 7 of Set 10 | ahuimanu
# Processing Record 8 of Set 10 | mehamn
# Processing Record 9 of Set 10 | gizo
# Processing Record 10 of Set 10 | rorvik
# Processing Record 11 of Set 10 | green river
# Processing Record 12 of Set 10 | fort nelson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 10 | pecos
# Processing Record 14 of Set 10 | goderich
# Processing Record 15 of Set 10 | dudinka
# Processing Record 16 of Set 10 | mgachi
# Processing Record 17 of Set 10 | marzuq
# City not found. Skipping...
# Processing Record 18 of Set 10 | gaya
# Processing Record 19 of Set 10 | grand gaube
# Processing Record 20 of Set 10 | abu samrah
# Processing Record 21 of Set 10 | huron
# Processing Record 22 of Set 10 | abnub
# Processing Record 23 of Set 10 | atar
# Processing Record 24 of Set 10 | znamenskoye
# Processing Record 25 of Set 10 | mingaora
# Processing Record 26 of Set 10 | rome
# Processing Record 27 of Set 10 | sola
# Processing Record 28 of Set 10 | launceston
# Processing Record 29 of Set 10 | saint-pierre
# Processing Record 30 of Set 10 | havelock
# Processing Record 31 of Set 10 | wisconsin rapids
# Processing Record 32 of Set 10 | tumaco
# Processing Record 33 of Set 10 | burnie
# Processing Record 34 of Set 10 | lakatoro
# Processing Record 35 of Set 10 | campbell river
# Processing Record 36 of Set 10 | tabou
# Processing Record 37 of Set 10 | ayan
# Processing Record 38 of Set 10 | hecun
# Processing Record 39 of Set 10 | cam pha
# Processing Record 40 of Set 10 | ulladulla
# Processing Record 41 of Set 10 | oranjemund
# Processing Record 42 of Set 10 | ukiah
# Processing Record 43 of Set 10 | bronderslev
# Processing Record 44 of Set 10 | arlit
# Processing Record 45 of Set 10 | mananjary
# Processing Record 46 of Set 10 | ancud
# Processing Record 47 of Set 10 | nytva
# Processing Record 48 of Set 10 | longyearbyen
# Processing Record 49 of Set 10 | kourou
# Processing Record 1 of Set 11 | wamba
# City not found. Skipping...
# Processing Record 2 of Set 11 | templin
# Processing Record 3 of Set 11 | inirida
# Processing Record 4 of Set 11 | pierre
# Processing Record 5 of Set 11 | vaitape
# Processing Record 6 of Set 11 | sayyan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 11 | manbij
# Processing Record 8 of Set 11 | roald
# Processing Record 9 of Set 11 | brae
# Processing Record 10 of Set 11 | tukrah
# Processing Record 11 of Set 11 | maragogi
# Processing Record 12 of Set 11 | yulara
# Processing Record 13 of Set 11 | mayo
# City not found. Skipping...
# Processing Record 14 of Set 11 | damaturu
# Processing Record 15 of Set 11 | lincoln
# Processing Record 16 of Set 11 | sengiley
# City not found. Skipping...
# Processing Record 17 of Set 11 | sena madureira
# Processing Record 18 of Set 11 | nanortalik
# Processing Record 19 of Set 11 | kyra
# Processing Record 20 of Set 11 | marawi
# Processing Record 21 of Set 11 | aojiang
# Processing Record 22 of Set 11 | kabompo
# Processing Record 23 of Set 11 | bowen
# Processing Record 24 of Set 11 | berekum
# Processing Record 25 of Set 11 | lodja
# Processing Record 26 of Set 11 | krasnyy yar
# Processing Record 27 of Set 11 | osorno
# Processing Record 28 of Set 11 | susanville
# Processing Record 29 of Set 11 | half moon bay
# Processing Record 30 of Set 11 | baoding
# Processing Record 31 of Set 11 | calatayud
# Processing Record 32 of Set 11 | finschhafen
# Processing Record 33 of Set 11 | aras
# Processing Record 34 of Set 11 | mossendjo
# Processing Record 35 of Set 11 | sampit
# Processing Record 36 of Set 11 | aksu
# Processing Record 37 of Set 11 | xai-xai
# Processing Record 38 of Set 11 | rindal
# Processing Record 39 of Set 11 | khandbari
# Processing Record 40 of Set 11 | chapais
# Processing Record 41 of Set 11 | san juan
# Processing Record 42 of Set 11 | novikovo
# Processing Record 43 of Set 11 | huitzo
# Processing Record 44 of Set 11 | pauini
# Processing Record 45 of Set 11 | yeppoon
# Processing Record 46 of Set 11 | hervey bay
# Processing Record 47 of Set 11 | omoa
# Processing Record 48 of Set 11 | swan river
# Processing Record 49 of Set 11 | belaya gora
# City not found. Skipping...
# Processing Record 1 of Set 12 | dzaoudzi
# Processing Record 2 of Set 12 | winthrop
# Processing Record 3 of Set 12 | adelaide
# Processing Record 4 of Set 12 | markivka
# Processing Record 5 of Set 12 | kuytun
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 12 | sidi ali
# Processing Record 7 of Set 12 | aklavik
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
cities
# Out:
# ['ostrovnoy',
#  'cidreira',
#  'hilo',
#  'rikitea',
#  'tabiauea',
#  'jamestown',
#  'clarence town',
#  'puerto ayora',
#  'mahebourg',
#  'skibbereen',
#  'thompson',
#  'lambarene',
#  'carnarvon',
#  'punta arenas',
#  'kozhva',
#  'sao joao da barra',
#  'deputatskiy',
#  'acapulco',
#  'barentsburg',
#  'buchanan',
#  'prince rupert',
#  'luderitz',
#  'port elizabeth',
#  'ushuaia',
#  'nizhneudinsk',
#  'busselton',
#  'butaritari',
#  'east london',
#  'cape town',
#  'albany',
#  'avera',
#  'barrow',
#  'bredasdorp',
#  'vaini',
#  'meulaboh',
#  'hobart',
#  'bangassou',
#  'hithadhoo',
#  'grand river south east',
#  'bilma',
#  'lebu',
#  'vao',
#  'tromso',
#  'amderma',
#  'inhambane',
#  'faanui',
#  'lavrentiya',
#  'chifeng',
#  'murfreesboro',
#  'gimli',
#  'cayenne',
#  'hermanus',
#  'quatre cocos',
#  'port alfred',
#  'qaanaaq',
#  'souillac',
#  'haysville',
#  'guerrero negro',
#  'kysyl-syr',
#  'kruisfontein',
#  'mataura',
#  'sosua',
#  'san quintin',
#  'himora',
#  'latung',
#  'lahaina',
#  'ayabaca',
#  'yerbogachen',
#  'altamont',
#  'atuona',
#  'puerto el triunfo',
#  'narsaq',
#  'dikson',
#  'jaggayyapeta',
#  'digras',
#  'kaitangata',
#  'talawdi',
#  'castro',
#  'muisne',
#  'loukhi',
#  'oistins',
#  'taolanaro',
#  'talara',
#  'opuwo',
#  'sao filipe',
#  'buraydah',
#  'nagamangala',
#  'kapaa',
#  'ravar',
#  'tommot',
#  'bundaberg',
#  'gwadar',
#  'mys shmidta',
#  'upernavik',
#  'omsukchan',
#  'yellowknife',
#  'otradnoye',
#  'hovd',
#  'rjukan',
#  'chimore',
#  'galiwinku',
#  'avarua',
#  'hokitika',
#  'hasaki',
#  'chuy',
#  'roma',
#  'padang',
#  'bocaranga',
#  'urfa',
#  'karratha',
#  'victoria',
#  'norman wells',
#  'cabo san lucas',
#  'gladstone',
#  'tuktoyaktuk',
#  'ardesen',
#  'bluff',
#  'codajas',
#  'azul',
#  'leninskoye',
#  'torbay',
#  'saskylakh',
#  'nikolskoye',
#  'vila velha',
#  'arraial do cabo',
#  'linguere',
#  'zalantun',
#  'karlskoga',
#  'palabuhanratu',
#  'beringovskiy',
#  'geraldton',
#  'saleaula',
#  'nara',
#  'belushya guba',
#  'sangre grande',
#  'batesville',
#  'novyy starodub',
#  'drumnadrochit',
#  'salamanca',
#  'yar-sale',
#  'khasan',
#  'kahului',
#  'harper',
#  'sept-iles',
#  'kadnikov',
#  'portage',
#  'gat',
#  'westport',
#  'illoqqortoormiut',
#  'kalivia',
#  'hamilton',
#  'kirakira',
#  'sur',
#  'chokurdakh',
#  'umm kaddadah',
#  'rudsar',
#  'sinnamary',
#  'tura',
#  'surt',
#  'kharp',
#  'georgetown',
#  'portland',
#  'kavieng',
#  'san patricio',
#  'ribeira grande',
#  'vostok',
#  'kailua',
#  'oxford',
#  'churapcha',
#  'okha',
#  'bristol',
#  'ketchikan',
#  'qaqortoq',
#  'grand-santi',
#  'kodiak',
#  'gurgan',
#  'severnyy',
#  'airai',
#  'puerto escondido',
#  'zeya',
#  'ilulissat',
#  'mwanza',
#  'solnechnyy',
#  'pevek',
#  'santiago del estero',
#  'cleethorpes',
#  'vaitupu',
#  'pangody',
#  'tumannyy',
#  'new norfolk',
#  'saint-joseph',
#  'saint george',
#  'pirgos',
#  'general pico',
#  'srednekolymsk',
#  'port keats',
#  'ajaccio',
#  'naze',
#  'mahon',
#  'sobolevo',
#  'cherskiy',
#  'linxia',
#  'fortuna',
#  'isangel',
#  'burica',
#  'asau',
#  'itaituba',
#  'ust-kuyga',
#  'saint-philippe',
#  'nago',
#  'port hedland',
#  'elbistan',
#  'niquelandia',
#  'addi ugri',
#  'verkh-usugli',
#  'yenagoa',
#  'santa maria',
#  'pangnirtung',
#  'moses lake',
#  'saint-augustin',
#  'bandarbeyla',
#  'batemans bay',
#  'nguiu',
#  'sovetskiy',
#  'hofn',
#  'shimoda',
#  'umzimvubu',
#  'ranfurly',
#  'henties bay',
#  'gambela',
#  'umm lajj',
#  'flin flon',
#  'tasiilaq',
#  'hobyo',
#  'san rafael',
#  'ust-nera',
#  'jalu',
#  'khatanga',
#  'kingaroy',
#  'dunmore east',
#  'shache',
#  'ust-maya',
#  'bathsheba',
#  'fairbanks',
#  'severo-kurilsk',
#  'panzhihua',
#  'chagda',
#  'mar del plata',
#  'bengkulu',
#  'ponta do sol',
#  'sentyabrskiy',
#  'salamiyah',
#  'katobu',
#  'saldanha',
#  'attawapiskat',
#  'kununurra',
#  'emba',
#  'sitka',
#  'rio grande',
#  'reftinskiy',
#  'puerto ayacucho',
#  'mandan',
#  'cozumel',
#  'muros',
#  'kulaman',
#  'amot',
#  'karpathos',
#  'itinga',
#  'rawson',
#  'semey',
#  'mudanjiang',
#  'alta floresta',
#  'isla mujeres',
#  'marsh harbour',
#  'ranong',
#  'belyy yar',
#  'broome',
#  'ugoofaaru',
#  'monte cristi',
#  'namibe',
#  'sao joao del rei',
#  'codrington',
#  'marienburg',
#  'visnes',
#  'kargasok',
#  'apac',
#  'vestmannaeyjar',
#  'jutai',
#  'sinjai',
#  'miranda',
#  'ust-kachka',
#  'manokwari',
#  'kipini',
#  'nabire',
#  'marsa matruh',
#  'gigmoto',
#  'brigantine',
#  'mindelo',
#  'grindavik',
#  'benguela',
#  'date',
#  'nome',
#  'merauke',
#  'california city',
#  'loralai',
#  'clyde river',
#  'springbok',
#  'faridabad',
#  'andarab',
#  'kazalinsk',
#  'jumla',
#  'itarema',
#  'beyneu',
#  'coihaique',
#  'viedma',
#  'oum hadjer',
#  'angola',
#  'kitale',
#  'charters towers',
#  'kampong thum',
#  'tolaga bay',
#  'visby',
#  'te anau',
#  'lata',
#  'fasa',
#  'provideniya',
#  'yuncheng',
#  'port lincoln',
#  'bethel',
#  'hambantota',
#  'paengaroa',
#  'lufilufi',
#  'berdigestyakh',
#  'lompoc',
#  'tiksi',
#  'santo domingo de guzman',
#  'vila franca do campo',
#  'bonavista',
#  'olafsvik',
#  'rennes',
#  'angoche',
#  'kirkuk',
#  'houyet',
#  'coquimbo',
#  'mount gambier',
#  'camacha',
#  'salalah',
#  'san andres',
#  'irece',
#  'laguna',
#  'garmsar',
#  'esperance',
#  'calabar',
#  'dawlatabad',
#  'sergeyevka',
#  'petropavlovsk-kamchatskiy',
#  'puerto del rosario',
#  'oloron-sainte-marie',
#  'byron bay',
#  'suzu',
#  'berbera',
#  'walvis bay',
#  'veinticinco de mayo',
#  'wanning',
#  'okhotsk',
#  'nanakuli',
#  'jabinyanah',
#  'bintulu',
#  'kirillov',
#  'novyy urgal',
#  'lasa',
#  'tocopilla',
#  'dasoguz',
#  'manono',
#  'ardistan',
#  'dwarka',
#  'pedernales',
#  'krasnoselkup',
#  'alofi',
#  'nacozari',
#  'ahipara',
#  'tombouctou',
#  'sydney',
#  'davila',
#  'nizhneyansk',
#  'rieti',
#  'mawlaik',
#  'tabas',
#  'baculin',
#  'villa florida',
#  'lagoa',
#  'kayerkan',
#  'constitucion',
#  'port macquarie',
#  'anse-bertrand',
#  'dingle',
#  'sakharovo',
#  'bolshaya irba',
#  'molina',
#  'murmashi',
#  'amambai',
#  'craigieburn',
#  'tessalit',
#  'meyungs',
#  'aswan',
#  'bangui',
#  'akdepe',
#  'bambous virieux',
#  'sarangani',
#  'richards bay',
#  'mareeba',
#  'kamenskoye',
#  'fukue',
#  'safaga',
#  'mazatan',
#  'khani',
#  'vicente guerrero',
#  'sjenica',
#  'eatonton',
#  'rungata',
#  'port pirie',
#  'pisco',
#  'zhanakorgan',
#  'maymyo',
#  'husavik',
#  'sheridan',
#  'katsuura',
#  'louisbourg',
#  'abu dhabi',
#  'teya',
#  'vung tau',
#  'yaguara',
#  'central point',
#  'suzaka',
#  'svetlyy',
#  'vila do maio',
#  'batagay',
#  'shakawe',
#  'kurilsk',
#  'aykhal',
#  'mugumu',
#  'farah',
#  'klyuchi',
#  'tuatapere',
#  'moussoro',
#  'mitsamiouli',
#  'sarh',
#  'dossor',
#  'tornio',
#  'caravelas',
#  'uhlove',
#  'cabedelo',
#  'sfantu gheorghe',
#  'la ronge',
#  'san cristobal',
#  'bullhead city',
#  'mujiayingzi',
#  'samusu',
#  'camana',
#  'waddan',
#  'saint anthony',
#  'rio gallegos',
#  'kavaratti',
#  'mbandaka',
#  'tirthahalli',
#  'erzin',
#  'moron',
#  'lokosovo',
#  'terrace bay',
#  'ochakiv',
#  'oga',
#  'lomza',
#  'srandakan',
#  'kerikeri',
#  'rocha',
#  'tsihombe',
#  'missao velha',
#  'botwood',
#  'zyryanovsk',
#  'dauriya',
#  'formoso do araguaia',
#  'klaksvik',
#  'kedrovyy',
#  'imatra',
#  'iqaluit',
#  'taburao',
#  'broken hill',
#  'araouane',
#  'christchurch',
#  'gravelbourg',
#  'celestun',
#  'warqla',
#  'along',
#  'anadyr',
#  'bolu',
#  'lorengau',
#  'lipari',
#  'stoyba',
#  'budhgaon',
#  'sheopur',
#  'neyshabur',
#  'ambilobe',
#  'marsaxlokk',
#  'tubruq',
#  'gushikawa',
#  'alihe',
#  'kyrylivka',
#  'ahuimanu',
#  'mehamn',
#  'gizo',
#  'rorvik',
#  'green river',
#  'fort nelson',
#  'fray bentos',
#  'kuche',
#  'pecos',
#  'goderich',
#  'dudinka',
#  'mgachi',
#  'marzuq',
#  'azimur',
#  'gaya',
#  'grand gaube',
#  'abu samrah',
#  'huron',
#  'abnub',
#  'atar',
#  'znamenskoye',
#  'mingaora',
#  'rome',
#  'sola',
#  'launceston',
#  'saint-pierre',
#  'havelock',
#  'wisconsin rapids',
#  'tumaco',
#  'burnie',
#  'lakatoro',
#  'campbell river',
#  'tabou',
#  'ayan',
#  'hecun',
#  'cam pha',
#  'ulladulla',
#  'oranjemund',
#  'ukiah',
#  'bronderslev',
#  'arlit',
#  'mananjary',
#  'ancud',
#  'nytva',
#  'longyearbyen',
#  'kourou',
#  'wamba',
#  'solsvik',
#  'templin',
#  'inirida',
#  'pierre',
#  'vaitape',
#  'sayyan',
#  'great yarmouth',
#  'torbat-e jam',
#  'manbij',
#  'roald',
#  'brae',
#  'tukrah',
#  'maragogi',
#  'yulara',
#  'mayo',
#  'mazulskiy',
#  'damaturu',
#  'lincoln',
#  'sengiley',
#  'maghama',
#  'sena madureira',
#  'nanortalik',
#  'kyra',
#  'marawi',
#  'aojiang',
#  'kabompo',
#  'bowen',
#  'berekum',
#  'lodja',
#  'krasnyy yar',
#  'osorno',
#  'susanville',
#  'half moon bay',
#  'baoding',
#  'calatayud',
#  'finschhafen',
#  'aras',
#  'mossendjo',
#  'sampit',
#  'aksu',
#  'xai-xai',
#  'rindal',
#  'khandbari',
#  'chapais',
#  'san juan',
#  'novikovo',
#  'huitzo',
#  'pauini',
#  'yeppoon',
#  'hervey bay',
#  'omoa',
#  'swan river',
#  'belaya gora',
#  'am timan',
#  'dzaoudzi',
#  'winthrop',
#  'adelaide',
#  'markivka',
#  'kuytun',
#  'toliary',
#  'devils lake',
#  'sidi ali',
#  'aklavik']

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary for establishing dataframe
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# %%
# establish dataframe
weather_dataframe = pd.DataFrame(weather_dict)

# %%
# show the top of the dataframe
weather_dataframe.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  ostrovnoy         100      RU  1584135933        96  68.05   39.51
# 1   cidreira           0      BR  1584135933        87 -30.18  -50.21
# 2       hilo          40      US  1584135888        69  19.73 -155.09
# 3    rikitea          12      PF  1584135934        74 -23.12 -134.97
# 4  jamestown           1      US  1584135934        48  42.10  -79.24
#
#    Max Temp  Wind Speed
# 0     23.99       20.60
# 1     77.27        8.01
# 2     80.60       10.29
# 3     76.55       12.12
# 4     46.40       27.51

# %%
# output data to csv
weather_dataframe.to_csv('weather_data_file')

# %%
weather_dataframe.count()
# Out:
# City          546
# Cloudiness    546
# Country       546
# Date          546
# Humidity      546
# Lat           546
# Lng           546
# Max Temp      546
# Wind Speed    546
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (03/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig('fig1.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (03/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig('fig2.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (03/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig('fig3.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (03/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig('fig4.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
